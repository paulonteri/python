# %% [markdown]
# <a href="https://colab.research.google.com/github/paulonteri/python/blob/master/notebooks/Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Strings

# %% [markdown]
# ## Splitting Strings

# %%
'a,b,c'.split(',')
# Out:
# ['a', 'b', 'c']

# %%
'this is my string'.split()
# Out:
# ['this', 'is', 'my', 'string']

# %% [markdown]
# ## Joins

# %%
strings = ['do', 're', 'mi']

# %%
"". join(strings)
# Out:
# 'doremi'

# %%
" , ".join(strings)
# Out:
# 'do , re , mi'

# %%
'b'.join(['a'])
# Out:
# 'a'

# %% [markdown]
# ### To Int

# %%
print(type("12"))
print(type(int("12")))
# Out:
# <class 'str'>
# <class 'int'>

# %%
print(type(12))
print(type(str(12)))
# Out:
# <class 'int'>
# <class 'str'>
