# %% [markdown]
# <a href="https://colab.research.google.com/github/paulonteri/python/blob/master/notebooks/Creating_new_arrays_from_arrays.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Creating new arrays from arrays 😂😂

# %%
x = [1,2,3]
x
# Out:
# [1, 2, 3]

# %%
y = x
y
# Out:
# [1, 2, 3]

# %%
p = list(x)
p
# Out:
# [1, 2, 3]

# %%
y.append(10)

# %%
y
# Out:
# [1, 2, 3, 10]

# %%
x
# Out:
# [1, 2, 3, 10]

# %%
p
# Out:
# [1, 2, 3]

# %%
p.append(20)
p
# Out:
# [1, 2, 3, 20]

# %%
x
# Out:
# [1, 2, 3, 10]
